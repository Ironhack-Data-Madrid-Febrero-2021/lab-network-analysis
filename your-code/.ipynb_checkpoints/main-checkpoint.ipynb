# %% [markdown]
# # Network Analysis Lab
#
# Complete the following exercises to help solidify your understanding of network analysis.

# %%
#! conda list

# %%
# %%capture
# !pip install nxviz

# %%
# %%capture
# !pip install community

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import csv
from operator import itemgetter
from networkx.algorithms import community
# %config Inlinebackend.figure_format = 'retina'
import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %% [markdown]
# ## U.S. Mens Basketball Data Set
#
# In the `us_mens_basketball.csv` data set, each row represents an single basketball player's participation in a single event at a single Olympics.

# %%
basketball = pd.read_csv('us_mens_basketball.csv')

# %%
basketball.head()
# Out:
#      ID                                  Name Sex   Age  Height  Weight  \
# 0   351            Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 1  2636           Stephen Todd "Steve" Alford   M  19.0   185.0    74.0
# 2  2863                      Walter Ray Allen   M  25.0   192.0    93.0
# 3  3874  William Lloyd "Willie" Anderson, Jr.   M  21.0   200.0    86.0
# 4  4505                  Carmelo Kyan Anthony   M  20.0   203.0   109.0
#
#             Team  NOC        Games  Year  Season         City       Sport  \
# 0  United States  USA  2000 Summer  2000  Summer       Sydney  Basketball
# 1  United States  USA  1984 Summer  1984  Summer  Los Angeles  Basketball
# 2  United States  USA  2000 Summer  2000  Summer       Sydney  Basketball
# 3  United States  USA  1988 Summer  1988  Summer        Seoul  Basketball
# 4  United States  USA  2004 Summer  2004  Summer       Athina  Basketball
#
#                          Event   Medal
# 0  Basketball Men's Basketball    Gold
# 1  Basketball Men's Basketball    Gold
# 2  Basketball Men's Basketball    Gold
# 3  Basketball Men's Basketball  Bronze
# 4  Basketball Men's Basketball  Bronze

# %% [markdown]
# ## 1. Transform this data set into one that can be turned into a graph where the entities are represented by the Name field and the relationships are represented by whether the players played in the same Olympics together (Games field).
#
# Sort descending by the number of pairwise interactions. Which pair of players have competed in the most Olympics together?

# %%
my_list = basketball.columns.values.tolist()
print(my_list)
# Out:
# ['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal']

# %%
basketball.drop(['ID', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Year', 'Season', 'City', 'Sport', 
                 'Event', 'Medal'], axis=1, inplace=True)
basketball
# Out:
#                                      Name        Games
# 0              Julius Shareef Abdur-Rahim  2000 Summer
# 1             Stephen Todd "Steve" Alford  1984 Summer
# 2                        Walter Ray Allen  2000 Summer
# 3    William Lloyd "Willie" Anderson, Jr.  1988 Summer
# 4                    Carmelo Kyan Anthony  2004 Summer
# ..                                    ...          ...
# 217                Deron Michael Williams  2008 Summer
# 218                Deron Michael Williams  2012 Summer
# 219          Howard Earl "Howie" Williams  1952 Summer
# 220                  George "Jiff" Wilson  1964 Summer
# 221                   Osie Leon Wood, III  1984 Summer
#
# [222 rows x 2 columns]

# %%
basketball2 = basketball.copy()
basketball2.head()
# Out:
#                                    Name        Games
# 0            Julius Shareef Abdur-Rahim  2000 Summer
# 1           Stephen Todd "Steve" Alford  1984 Summer
# 2                      Walter Ray Allen  2000 Summer
# 3  William Lloyd "Willie" Anderson, Jr.  1988 Summer
# 4                  Carmelo Kyan Anthony  2004 Summer

# %%
basketball3=pd.merge(basketball2, basketball, on='Games')

# %%
basketball3
# Out:
#                           Name_x        Games                          Name_y
# 0     Julius Shareef Abdur-Rahim  2000 Summer      Julius Shareef Abdur-Rahim
# 1     Julius Shareef Abdur-Rahim  2000 Summer                Walter Ray Allen
# 2     Julius Shareef Abdur-Rahim  2000 Summer      Vincent Lamont "Vin" Baker
# 3     Julius Shareef Abdur-Rahim  2000 Summer    Vincent Lamar "Vince" Carter
# 4     Julius Shareef Abdur-Rahim  2000 Summer           Kevin Maurice Garnett
# ...                          ...          ...                             ...
# 2743   James Patrick "Jim" Walsh  1956 Summer  Robert Eugene "Bob" Jeangerard
# 2744   James Patrick "Jim" Walsh  1956 Summer                     K. C. Jones
# 2745   James Patrick "Jim" Walsh  1956 Summer   William Fenton "Bill" Russell
# 2746   James Patrick "Jim" Walsh  1956 Summer        Ronald Paul "Ron" Tomsic
# 2747   James Patrick "Jim" Walsh  1956 Summer       James Patrick "Jim" Walsh
#
# [2748 rows x 3 columns]

# %%
print(basketball3['Name_x'].dtypes)
# Out:
# object

# %%
print(basketball3['Name_y'].dtypes)
# Out:
# object

# %%
basketball3 = basketball3.query('Name_x != Name_y')
basketball3
# Out:
#                           Name_x        Games                          Name_y
# 1     Julius Shareef Abdur-Rahim  2000 Summer                Walter Ray Allen
# 2     Julius Shareef Abdur-Rahim  2000 Summer      Vincent Lamont "Vin" Baker
# 3     Julius Shareef Abdur-Rahim  2000 Summer    Vincent Lamar "Vince" Carter
# 4     Julius Shareef Abdur-Rahim  2000 Summer           Kevin Maurice Garnett
# 5     Julius Shareef Abdur-Rahim  2000 Summer    Timothy Duane "Tim" Hardaway
# ...                          ...          ...                             ...
# 2742   James Patrick "Jim" Walsh  1956 Summer  William Marion "Bill" Hougland
# 2743   James Patrick "Jim" Walsh  1956 Summer  Robert Eugene "Bob" Jeangerard
# 2744   James Patrick "Jim" Walsh  1956 Summer                     K. C. Jones
# 2745   James Patrick "Jim" Walsh  1956 Summer   William Fenton "Bill" Russell
# 2746   James Patrick "Jim" Walsh  1956 Summer        Ronald Paul "Ron" Tomsic
#
# [2526 rows x 3 columns]

# %%
#from nxviz import CircosPlot

#c = CircosPlot(G)
#c.draw()

# %%
#from nxviz import MatrixPlot

#m = MatrixPlot(G)
#m.draw()

# %%
#from nxviz import ArcPlot

#a = ArcPlot(G)
#a.draw()

# %% [markdown]
# ## 2. Use the `from_pandas_edgelist` method to turn the data frame into a graph.

# %%
G = nx.from_pandas_edgelist(basketball3,  source='Name_x', target='Name_y')

# %%
plt.figure(figsize=(10,5))
nx.draw(G, node_size=20, node_color='cyan')

# %%
#let’s create another dataframe that shows the nodes and their number of connections
Games_connections = {}
for x in G.nodes:
 Games_connections[x] = len(G[x])
s = pd.Series(Games_connections, name='connections')
df2 = s.to_frame().sort_values('connections', ascending=False)
df2.head()
# Out:
#                                 connections
# Carmelo Kyan Anthony                     36
# David Maurice Robinson                   28
# LeBron Raymone James                     26
# Robert Albert "Bob" Kurland              26
# William Marion "Bill" Hougland           24

# %% [markdown]
# ## 3. Compute and print the following graph statistics for the graph:
#
# - Number of nodes
# - Number of edges
# - Average degree
# - Density

# %%
print("Number of nodes: ",len(G.nodes))
print("Number of edges: ",len(G.edges))
# Out:
# Number of nodes:  196
# Number of edges:  1232

# %%
G_deg = nx.degree_histogram(G)
print(G_deg)
# Out:
# [0, 174, 19, 2, 1, 0, 0, 0, 0, 0, 0, 0, 15, 0, 3]

# %%
G_deg_sum = [a * b for a, b in zip(G_deg, range(0, len(G_deg)))]
print('average degree: {}'.format(sum(G_deg_sum) / G.number_of_nodes()))
# Out:
# average degree: 12.571428571428571

# %%
#same with this function
print(nx.info(G))
print("Density: ",nx.density(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 196
# Number of edges: 1232
# Average degree:  12.5714
# Density:  0.06446886446886448

# %% [markdown]
# ## 4. Compute betweenness centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
highest_betweenness_c=dict(sorted(nx.betweenness_centrality(G).items(), key=lambda item: item[1], reverse=True))

# %%
#max([i for i in highest_betweenness_c.values()])

# %%
for x in list(highest_betweenness_c)[0:5]:
    print (x)
# Out:
# Gary Dwayne Payton
# Jason Frederick Kidd
# Carmelo Kyan Anthony
# David Maurice Robinson
# William Marion "Bill" Hougland

# %% [markdown]
# ## 5. Compute Eigenvector centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
eigenvector = nx.eigenvector_centrality_numpy(G)
eigenvector
# Out:
# {'Julius Shareef Abdur-Rahim': 0.0392768637845984,
#  'Walter Ray Allen': 0.0392768637845984,
#  'Vincent Lamont "Vin" Baker': 0.03927686378459839,
#  'Vincent Lamar "Vince" Carter': 0.03927686378459837,
#  'Kevin Maurice Garnett': 0.039276863784598416,
#  'Timothy Duane "Tim" Hardaway': 0.03927686378459843,
#  'Allan Wade Houston': 0.03927686378459838,
#  'Jason Frederick Kidd': 0.1856692521470379,
#  'Antonio Keithflen McDyess': 0.039276863784598375,
#  'Alonzo Harding Mourning': 0.03927686378459839,
#  'Gary Dwayne Payton': 0.059696469379226784,
#  'Steven Delano "Steve" Smith': 0.03927686378459841,
#  'Stephen Todd "Steve" Alford': 0.011572567846822791,
#  'Patrick Aloysius Ewing': 0.027955776108382385,
#  'Vernon "Vern" Fleming': 0.011572567846822793,
#  'Michael Jeffrey Jordan': 0.02795577610838237,
#  'Joseph William "Joe" Kleine': 0.011572567846822802,
#  'Jon Francis Koncak': 0.011572567846822793,
#  'Christopher Paul "Chris" Mullin': 0.027955776108382388,
#  'Samuel Bruce "Sam" Perkins': 0.0115725678468228,
#  'Alvin Cyrrale Robertson': 0.011572567846822803,
#  'Wayman Lawrence Tisdale': 0.01157256784682278,
#  'Jeffrey Stephen "Jeff" Turner': 0.01157256784682279,
#  'Osie Leon Wood, III': 0.011572567846822783,
#  'William Lloyd "Willie" Anderson, Jr.': 0.011693205660835907,
#  'Stacey Orlando Augmon': 0.011693205660835912,
#  'Vernell Eufaye "Bimbo" Coles': 0.011693205660835907,
#  'Jeffrey "Jeff" Grayer': 0.011693205660835905,
#  'Hersey R. Hawkins, Jr.': 0.01169320566083591,
#  'Daniel Lewis "Dan" Majerle': 0.01169320566083591,
#  'Daniel Ricardo "Danny" Manning': 0.011693205660835914,
#  'Herman "J. R." Reid, Jr.': 0.011693205660835893,
#  'Mitchell James "Mitch" Richmond, III': 0.03129100666212984,
#  'David Maurice Robinson': 0.04175738792611297,
#  'Charles Daniel H. Smith': 0.011693205660835908,
#  'Charles Edward Smith, IV': 0.011693205660835905,
#  'Carmelo Kyan Anthony': 0.34185005667190727,
#  'Carlos Austin Boozer, Jr.': 0.22195694763560406,
#  'Timothy Theodore "Tim" Duncan': 0.1302542761621564,
#  'Allen Ezail Iverson': 0.1302542761621564,
#  'LeBron Raymone James': 0.28845352143158876,
#  'Richard Allen Jefferson': 0.13025427616215648,
#  'Stephon Xavier Marbury': 0.13025427616215646,
#  'Shawn Dwayne Marion': 0.13025427616215646,
#  'Lamar Joseph Odom': 0.13025427616215643,
#  'Chukwuemeka Noubuisi "Emeka" Okafor': 0.13025427616215648,
#  "Amar'e Carsares Stoudemire": 0.1302542761621565,
#  'Dwyane Tyrone Wade, Jr.': 0.22195694763560408,
#  'Christopher Wesson "Chris" Bosh': 0.1578202417893279,
#  'Kobe Bean Bryant': 0.22431681558531266,
#  'Dwight David Howard': 0.15782024178932777,
#  'Christopher Emmanuel "Chris" Paul': 0.22431681558531266,
#  'Tayshaun Durell Prince': 0.15782024178932788,
#  'Michael Wesley Redd': 0.1578202417893279,
#  'Deron Michael Williams': 0.2243168155853126,
#  'Tyson Cleotis Chandler': 0.14671123401501535,
#  'Anthony Marshon Davis, Jr.': 0.14671123401501535,
#  'Kevin Wayne Durant': 0.20010776925533366,
#  'James Edward Harden, Jr.': 0.14671123401501526,
#  'Andre Tyler Iguodala': 0.14671123401501537,
#  'Kevin Wesley Love': 0.14671123401501523,
#  'Russell Westbrook, Jr.': 0.1467112340150153,
#  'Harrison Bryce Jordan Barnes': 0.08675377951546034,
#  'Jimmy Butler III': 0.08675377951546032,
#  'DeMarcus Amir Cousins': 0.08675377951546027,
#  'DeMar Darnell DeRozan': 0.08675377951546032,
#  'Paul George': 0.08675377951546027,
#  'Draymond Jamal Green': 0.08675377951546036,
#  'Kyrie Andrew Irving': 0.0867537795154603,
#  'Hyland DeAndre Jordan, Jr.': 0.08675377951546027,
#  'Kyle Lowry': 0.08675377951546032,
#  'Klay Alexander Thompson': 0.08675377951546032,
#  'Michel Taylor "Tate" Armstrong': -2.915435484037226e-17,
#  'William Quinn Buckner': -2.3738311378356286e-17,
#  'Kenneth Alan "Kenny" Carr': -2.8768122008570245e-17,
#  'Adrian Delano Dantley': -2.3956552211326308e-17,
#  'Walter Paul Davis': -2.6082203625758192e-17,
#  'Philip Jackson "Phil" Ford, Jr.': -2.246428497794112e-17,
#  'Ernest "Ernie" Grunfeld': -2.4444571505588415e-17,
#  'Phillip Gregory "Phil" Hubbard': -2.758228726068632e-17,
#  'Mitchell William "Mitch" Kupchak': -2.6622348764180703e-17,
#  'Thomas Joseph "Tom" LaGarde': -2.508439356525416e-17,
#  'Scott Glenn May': -1.8740697237310525e-17,
#  'Steven Bernard "Steve" Sheppard': -2.7862194343315535e-17,
#  'Jay Joseph Hoyland Arnette': 4.669119443276353e-19,
#  'Walter Jones "Walt" Bellamy, Jr.': 6.246586109186153e-18,
#  'Robert Lewis "Bob" Boozer': 4.657791633739499e-18,
#  'Terence Gilbert "Terry" Dischinger': 5.57987674692671e-18,
#  'Burdette Eliele "Burdie" Haldorson': -1.8250519208119272e-16,
#  'Darrall Tucker Imhoff': 1.2190430399641092e-17,
#  'Earl Allen Kelley': 2.8935708032222276e-17,
#  'Lester Everett "Les" Lane': 1.8928671927819358e-17,
#  'Jerry Ray Lucas': 3.772188770684827e-18,
#  'Oscar Palmer Robertson': 1.4737792238407496e-17,
#  'Adrian Howard Smith': -7.95132968462863e-18,
#  'Jerome Alan "Jerry" West': 2.3475644208345935e-18,
#  'Samuel J. "Sam" Balter, Jr.': -3.028602112259553e-17,
#  'Ralph English Bishop': -2.2068431869368223e-17,
#  'Joseph Cephis "Joe" Fortenberry': -3.2942829711759544e-17,
#  'John Haskell "Tex" Gibbons': -2.7921070534491817e-17,
#  'Francis Lee Johnson': -3.3828432574814217e-17,
#  'Carl Stanley Knowles': -2.4561070332935815e-17,
#  'Frank John Lubin': -3.213019134896995e-17,
#  'Arthur Owen "Art" Mollner': -2.4524588082803277e-17,
#  'Donald Arthur "Don" Piper': -2.036118535496112e-18,
#  'Jack Williamson Ragland': -2.4652275958267158e-17,
#  'Willard Theodore Schmidt': -2.0625566394451718e-17,
#  'Carl Leslie Shy': -5.70565759846459e-17,
#  'Duane Alexander Swanson': -1.6252275454377166e-17,
#  'William John "Bill" Wheatley': -3.5435468175327137e-17,
#  'Michael Allen "Mike" Bantom': -1.260328963652438e-17,
#  'James Turner "Jim" Brewer': -1.4265584720799016e-17,
#  'Tommy Loren Burleson': -1.5447160538241044e-17,
#  'Paul Douglas "Doug" Collins': -1.3955622328881792e-17,
#  'Kenneth Bryan "Kenny" Davis': -1.57697353985337e-17,
#  'James Ricardo "Jim" Forbes': -1.1592924904056396e-17,
#  'Thomas Edward "Tom" Henderson': -1.5047031692518034e-17,
#  'Robert Clyde "Bobby" Jones': -1.2772487858261864e-17,
#  'Dwight Elmo Jones': -1.2824898866833952e-17,
#  'Kevin Francis Joyce': -1.6078304634883502e-17,
#  'Charles Thomas "Tom" McMillen': -1.2242185063492924e-17,
#  'William Edward "Ed" Ratleff': -6.3434646862221204e-18,
#  'Clifford Eugene "Cliff" Barker': -5.228741273958549e-16,
#  'Donald Argee "Don" Barksdale': -5.225822693947946e-16,
#  'Ralph Milton Beard, Jr.': -5.228741273958549e-16,
#  'Lewis William "Lew" Beck, Jr.': -5.163730204935381e-16,
#  'Vincent Joseph "Vince" Boryla': -4.829919119787733e-16,
#  'Gordon C. Carpenter': -5.231659853969152e-16,
#  'Alexander John "Alex" Groza': -4.894930188810901e-16,
#  'Wallace Clayton "Wally" Jones': -5.292293052976415e-16,
#  'Robert Albert "Bob" Kurland': -1.0746835311527044e-15,
#  'Raymond George "Ray" Lumpp': -5.024952326857236e-16,
#  'Robert C. "R. C." Pitts': -5.027870906867839e-16,
#  'Jesse Banard Renick': -4.894930188810901e-16,
#  'Robert Lloyd Jackson "Jack" Robinson': -5.16227091493008e-16,
#  'Kenneth Herman "Kenny" Rollins': -5.292293052976415e-16,
#  'Charles Wade Barkley': 0.034560275919830345,
#  'Larry Joe Bird': 0.0215452020991041,
#  'Clyde Austin Drexler': 0.021545202099104113,
#  'Earvin "Magic" Johnson, Jr.': 0.021545202099104106,
#  'Christian Donald Laettner': 0.021545202099104113,
#  'Karl Malone': 0.034560275919830366,
#  'Scottie Maurice Pippen': 0.034560275919830345,
#  'John Houston Stockton': 0.034560275919830366,
#  'Anfernee Deon "Penny" Hardaway': 0.02409389465584722,
#  'Grant Henry Hill': 0.024093894655847204,
#  'Reginald Wayne "Reggie" Miller': 0.02409389465584721,
#  'Hakeem Abdul Olajuwon': 0.024093894655847225,
#  "Shaquille Rashuan O'Neal": 0.02409389465584721,
#  'Velvet James "Jim" Barnes': 1.144332166140859e-17,
#  'William Warren "Bill" Bradley': 8.951262543588112e-18,
#  'Lawrence Harvey "Larry" Brown': 1.1284077840139065e-17,
#  'Joseph Louis "Joe" Caldwell': 6.11311838347952e-18,
#  'Melvin Grant "Mel" Counts': 7.251731495732123e-18,
#  'Richard Allen "Dick" Davies': 1.369035974550632e-17,
#  'Walter Raphael "Walt" Hazzard': 1.0110098341867359e-17,
#  'Lucious Brown "Luke" Jackson, Jr.': 1.3517222020721186e-17,
#  'John Paul "Pete" McCaffrey': 1.1833555940064246e-17,
#  'Jeffrey Vincent "Jeff" Mullins': 1.0489734820096556e-17,
#  'Jerry Franklin Shipp': 9.671738185551755e-18,
#  'George "Jiff" Wilson': 1.735371497421595e-17,
#  'Michael Thomas "Mike" Barrett': 1.9385407816195468e-17,
#  'John Richard Clawson': 1.4961374864911218e-17,
#  'Donald Francis "Don" Dee': 7.879033434135868e-18,
#  'Calvin Bernard "Cal" Fowler': 1.656336899674395e-17,
#  'Spencer Haywood': 1.1039447115178381e-17,
#  'Wilmer Frederick "Bill" Hosket': 9.449042172943448e-18,
#  'James H. "Jim" King': 1.7654315059981523e-17,
#  'Glynn Saulters': 1.5098130608302698e-17,
#  'Charles Thomas "Charlie" Scott': 1.1032744247094698e-17,
#  'Michael Barnwell "Mike" Silliman': 1.4358414988947155e-17,
#  'John Kenneth "Ken" Spain': 1.626062828178846e-17,
#  'Joseph Henry "Jo-Jo" White': 1.091928071373145e-17,
#  'Ronald Yngve "Ron" Bontemps': -6.547415688359462e-16,
#  'Marcus Ross "Marc" Freiberger': -6.352382481289958e-16,
#  'Victor Wayne Glasgow': -6.553252848380668e-16,
#  'Charles Monroe "Charlie" Hoag': -6.748286055450171e-16,
#  'William Marion "Bill" Hougland': -7.662503041528612e-16,
#  'John Frederick Keller': -6.281534252245585e-16,
#  'Melvin Dean Kelley': -6.217982473227718e-16,
#  'Robert Earl "Bob" Kenney': -6.213604603211814e-16,
#  'William Barner "Bill" Lienhard': -6.420312130323729e-16,
#  'Clyde Edward Lovellette': -6.745367475439568e-16,
#  'Frank Reilly McCabe': -6.150052824193948e-16,
#  'Dan Luther Pippin': -6.014193526126406e-16,
#  'Howard Earl "Howie" Williams': -6.678897116411099e-16,
#  'Richard James "Dick" Boushka': -1.6417508357731713e-16,
#  'Carl Cecil Cain': -1.5405860072251658e-16,
#  'Charles Frick "Chuck" Darling': -1.6432101257784728e-16,
#  'William Best "Billy" Evans': -1.7104101298095928e-16,
#  'Gilbert "Gib" Ford': -1.575280476744702e-16,
#  'Robert Eugene "Bob" Jeangerard': -1.6757156602900566e-16,
#  'K. C. Jones': -1.475574938201998e-16,
#  'William Fenton "Bill" Russell': -1.6764453052927074e-16,
#  'Ronald Paul "Ron" Tomsic': -1.6092453012615874e-16,
#  'James Patrick "Jim" Walsh': -1.5760101217473527e-16}

# %% [markdown]
# ## 6. Compute degree centrality for the graph and print the top 5 nodes with the highest centrality.

# %%
degree_centrality=dict(sorted(nx.closeness_centrality(G).items(), key=lambda item: item[1], reverse=True))

# %%
degree_centrality
# Out:
# {'Gary Dwayne Payton': 0.20102564102564105,
#  'Jason Frederick Kidd': 0.19991500212494687,
#  'David Maurice Robinson': 0.18002296211251437,
#  'Carmelo Kyan Anthony': 0.17737556561085974,
#  'Charles Wade Barkley': 0.17149106817353263,
#  'Karl Malone': 0.17149106817353263,
#  'Scottie Maurice Pippen': 0.17149106817353263,
#  'John Houston Stockton': 0.17149106817353263,
#  'LeBron Raymone James': 0.16908698777857656,
#  'Julius Shareef Abdur-Rahim': 0.16674937965260547,
#  'Walter Ray Allen': 0.16674937965260547,
#  'Vincent Lamont "Vin" Baker': 0.16674937965260547,
#  'Vincent Lamar "Vince" Carter': 0.16674937965260547,
#  'Kevin Maurice Garnett': 0.16674937965260547,
#  'Timothy Duane "Tim" Hardaway': 0.16674937965260547,
#  'Allan Wade Houston': 0.16674937965260547,
#  'Antonio Keithflen McDyess': 0.16674937965260547,
#  'Alonzo Harding Mourning': 0.16674937965260547,
#  'Steven Delano "Steve" Smith': 0.16674937965260547,
#  'Mitchell James "Mitch" Richmond, III': 0.16674937965260547,
#  'William Marion "Bill" Hougland': 0.1641025641025641,
#  'Carlos Austin Boozer, Jr.': 0.1637312913331013,
#  'Dwyane Tyrone Wade, Jr.': 0.1637312913331013,
#  'Kobe Bean Bryant': 0.162993762993763,
#  'Christopher Emmanuel "Chris" Paul': 0.162993762993763,
#  'Deron Michael Williams': 0.162993762993763,
#  'Anfernee Deon "Penny" Hardaway': 0.15940359200271095,
#  'Grant Henry Hill': 0.15940359200271095,
#  'Reginald Wayne "Reggie" Miller': 0.15940359200271095,
#  'Hakeem Abdul Olajuwon': 0.15940359200271095,
#  "Shaquille Rashuan O'Neal": 0.15940359200271095,
#  'Christopher Wesson "Chris" Bosh': 0.15801142089351697,
#  'Dwight David Howard': 0.15801142089351697,
#  'Tayshaun Durell Prince': 0.15801142089351697,
#  'Michael Wesley Redd': 0.15801142089351697,
#  'Robert Albert "Bob" Kurland': 0.14586894586894586,
#  'Patrick Aloysius Ewing': 0.14134615384615384,
#  'Michael Jeffrey Jordan': 0.14134615384615384,
#  'Christopher Paul "Chris" Mullin': 0.14134615384615384,
#  'Larry Joe Bird': 0.1365457184325109,
#  'Clyde Austin Drexler': 0.1365457184325109,
#  'Earvin "Magic" Johnson, Jr.': 0.1365457184325109,
#  'Christian Donald Laettner': 0.1365457184325109,
#  'Burdette Eliele "Burdie" Haldorson': 0.13580901856763927,
#  'Kevin Wayne Durant': 0.13552290406222992,
#  'William Lloyd "Willie" Anderson, Jr.': 0.13206064008983717,
#  'Stacey Orlando Augmon': 0.13206064008983717,
#  'Vernell Eufaye "Bimbo" Coles': 0.13206064008983717,
#  'Jeffrey "Jeff" Grayer': 0.13206064008983717,
#  'Hersey R. Hawkins, Jr.': 0.13206064008983717,
#  'Daniel Lewis "Dan" Majerle': 0.13206064008983717,
#  'Daniel Ricardo "Danny" Manning': 0.13206064008983717,
#  'Herman "J. R." Reid, Jr.': 0.13206064008983717,
#  'Charles Daniel H. Smith': 0.13206064008983717,
#  'Charles Edward Smith, IV': 0.13206064008983717,
#  'Timothy Theodore "Tim" Duncan': 0.13063038044987504,
#  'Allen Ezail Iverson': 0.13063038044987504,
#  'Richard Allen Jefferson': 0.13063038044987504,
#  'Stephon Xavier Marbury': 0.13063038044987504,
#  'Shawn Dwayne Marion': 0.13063038044987504,
#  'Lamar Joseph Odom': 0.13063038044987504,
#  'Chukwuemeka Noubuisi "Emeka" Okafor': 0.13063038044987504,
#  "Amar'e Carsares Stoudemire": 0.13063038044987504,
#  'Tyson Cleotis Chandler': 0.13063038044987504,
#  'Anthony Marshon Davis, Jr.': 0.13063038044987504,
#  'James Edward Harden, Jr.': 0.13063038044987504,
#  'Andre Tyler Iguodala': 0.13063038044987504,
#  'Kevin Wesley Love': 0.13063038044987504,
#  'Russell Westbrook, Jr.': 0.13063038044987504,
#  'Harrison Bryce Jordan Barnes': 0.13063038044987504,
#  'Jimmy Butler III': 0.13063038044987504,
#  'DeMarcus Amir Cousins': 0.13063038044987504,
#  'DeMar Darnell DeRozan': 0.13063038044987504,
#  'Paul George': 0.13063038044987504,
#  'Draymond Jamal Green': 0.13063038044987504,
#  'Kyrie Andrew Irving': 0.13063038044987504,
#  'Hyland DeAndre Jordan, Jr.': 0.13063038044987504,
#  'Kyle Lowry': 0.13063038044987504,
#  'Klay Alexander Thompson': 0.13063038044987504,
#  'Ronald Yngve "Ron" Bontemps': 0.12569558101472994,
#  'Marcus Ross "Marc" Freiberger': 0.12569558101472994,
#  'Victor Wayne Glasgow': 0.12569558101472994,
#  'Charles Monroe "Charlie" Hoag': 0.12569558101472994,
#  'John Frederick Keller': 0.12569558101472994,
#  'Melvin Dean Kelley': 0.12569558101472994,
#  'Robert Earl "Bob" Kenney': 0.12569558101472994,
#  'William Barner "Bill" Lienhard': 0.12569558101472994,
#  'Clyde Edward Lovellette': 0.12569558101472994,
#  'Frank Reilly McCabe': 0.12569558101472994,
#  'Dan Luther Pippin': 0.12569558101472994,
#  'Howard Earl "Howie" Williams': 0.12569558101472994,
#  'Richard James "Dick" Boushka': 0.12056514913657772,
#  'Carl Cecil Cain': 0.12056514913657772,
#  'Charles Frick "Chuck" Darling': 0.12056514913657772,
#  'William Best "Billy" Evans': 0.12056514913657772,
#  'Gilbert "Gib" Ford': 0.12056514913657772,
#  'Robert Eugene "Bob" Jeangerard': 0.12056514913657772,
#  'K. C. Jones': 0.12056514913657772,
#  'William Fenton "Bill" Russell': 0.12056514913657772,
#  'Ronald Paul "Ron" Tomsic': 0.12056514913657772,
#  'James Patrick "Jim" Walsh': 0.12056514913657772,
#  'Stephen Todd "Steve" Alford': 0.1099836333878887,
#  'Vernon "Vern" Fleming': 0.1099836333878887,
#  'Joseph William "Joe" Kleine': 0.1099836333878887,
#  'Jon Francis Koncak': 0.1099836333878887,
#  'Samuel Bruce "Sam" Perkins': 0.1099836333878887,
#  'Alvin Cyrrale Robertson': 0.1099836333878887,
#  'Wayman Lawrence Tisdale': 0.1099836333878887,
#  'Jeffrey Stephen "Jeff" Turner': 0.1099836333878887,
#  'Osie Leon Wood, III': 0.1099836333878887,
#  'Clifford Eugene "Cliff" Barker': 0.10185676392572944,
#  'Donald Argee "Don" Barksdale': 0.10185676392572944,
#  'Ralph Milton Beard, Jr.': 0.10185676392572944,
#  'Lewis William "Lew" Beck, Jr.': 0.10185676392572944,
#  'Vincent Joseph "Vince" Boryla': 0.10185676392572944,
#  'Gordon C. Carpenter': 0.10185676392572944,
#  'Alexander John "Alex" Groza': 0.10185676392572944,
#  'Wallace Clayton "Wally" Jones': 0.10185676392572944,
#  'Raymond George "Ray" Lumpp': 0.10185676392572944,
#  'Robert C. "R. C." Pitts': 0.10185676392572944,
#  'Jesse Banard Renick': 0.10185676392572944,
#  'Robert Lloyd Jackson "Jack" Robinson': 0.10185676392572944,
#  'Kenneth Herman "Kenny" Rollins': 0.10185676392572944,
#  'Jay Joseph Hoyland Arnette': 0.09528535980148883,
#  'Walter Jones "Walt" Bellamy, Jr.': 0.09528535980148883,
#  'Robert Lewis "Bob" Boozer': 0.09528535980148883,
#  'Terence Gilbert "Terry" Dischinger': 0.09528535980148883,
#  'Darrall Tucker Imhoff': 0.09528535980148883,
#  'Earl Allen Kelley': 0.09528535980148883,
#  'Lester Everett "Les" Lane': 0.09528535980148883,
#  'Jerry Ray Lucas': 0.09528535980148883,
#  'Oscar Palmer Robertson': 0.09528535980148883,
#  'Adrian Howard Smith': 0.09528535980148883,
#  'Jerome Alan "Jerry" West': 0.09528535980148883,
#  'Samuel J. "Sam" Balter, Jr.': 0.06666666666666667,
#  'Ralph English Bishop': 0.06666666666666667,
#  'Joseph Cephis "Joe" Fortenberry': 0.06666666666666667,
#  'John Haskell "Tex" Gibbons': 0.06666666666666667,
#  'Francis Lee Johnson': 0.06666666666666667,
#  'Carl Stanley Knowles': 0.06666666666666667,
#  'Frank John Lubin': 0.06666666666666667,
#  'Arthur Owen "Art" Mollner': 0.06666666666666667,
#  'Donald Arthur "Don" Piper': 0.06666666666666667,
#  'Jack Williamson Ragland': 0.06666666666666667,
#  'Willard Theodore Schmidt': 0.06666666666666667,
#  'Carl Leslie Shy': 0.06666666666666667,
#  'Duane Alexander Swanson': 0.06666666666666667,
#  'William John "Bill" Wheatley': 0.06666666666666667,
#  'Michel Taylor "Tate" Armstrong': 0.05641025641025641,
#  'William Quinn Buckner': 0.05641025641025641,
#  'Kenneth Alan "Kenny" Carr': 0.05641025641025641,
#  'Adrian Delano Dantley': 0.05641025641025641,
#  'Walter Paul Davis': 0.05641025641025641,
#  'Philip Jackson "Phil" Ford, Jr.': 0.05641025641025641,
#  'Ernest "Ernie" Grunfeld': 0.05641025641025641,
#  'Phillip Gregory "Phil" Hubbard': 0.05641025641025641,
#  'Mitchell William "Mitch" Kupchak': 0.05641025641025641,
#  'Thomas Joseph "Tom" LaGarde': 0.05641025641025641,
#  'Scott Glenn May': 0.05641025641025641,
#  'Steven Bernard "Steve" Sheppard': 0.05641025641025641,
#  'Michael Allen "Mike" Bantom': 0.05641025641025641,
#  'James Turner "Jim" Brewer': 0.05641025641025641,
#  'Tommy Loren Burleson': 0.05641025641025641,
#  'Paul Douglas "Doug" Collins': 0.05641025641025641,
#  'Kenneth Bryan "Kenny" Davis': 0.05641025641025641,
#  'James Ricardo "Jim" Forbes': 0.05641025641025641,
#  'Thomas Edward "Tom" Henderson': 0.05641025641025641,
#  'Robert Clyde "Bobby" Jones': 0.05641025641025641,
#  'Dwight Elmo Jones': 0.05641025641025641,
#  'Kevin Francis Joyce': 0.05641025641025641,
#  'Charles Thomas "Tom" McMillen': 0.05641025641025641,
#  'William Edward "Ed" Ratleff': 0.05641025641025641,
#  'Velvet James "Jim" Barnes': 0.05641025641025641,
#  'William Warren "Bill" Bradley': 0.05641025641025641,
#  'Lawrence Harvey "Larry" Brown': 0.05641025641025641,
#  'Joseph Louis "Joe" Caldwell': 0.05641025641025641,
#  'Melvin Grant "Mel" Counts': 0.05641025641025641,
#  'Richard Allen "Dick" Davies': 0.05641025641025641,
#  'Walter Raphael "Walt" Hazzard': 0.05641025641025641,
#  'Lucious Brown "Luke" Jackson, Jr.': 0.05641025641025641,
#  'John Paul "Pete" McCaffrey': 0.05641025641025641,
#  'Jeffrey Vincent "Jeff" Mullins': 0.05641025641025641,
#  'Jerry Franklin Shipp': 0.05641025641025641,
#  'George "Jiff" Wilson': 0.05641025641025641,
#  'Michael Thomas "Mike" Barrett': 0.05641025641025641,
#  'John Richard Clawson': 0.05641025641025641,
#  'Donald Francis "Don" Dee': 0.05641025641025641,
#  'Calvin Bernard "Cal" Fowler': 0.05641025641025641,
#  'Spencer Haywood': 0.05641025641025641,
#  'Wilmer Frederick "Bill" Hosket': 0.05641025641025641,
#  'James H. "Jim" King': 0.05641025641025641,
#  'Glynn Saulters': 0.05641025641025641,
#  'Charles Thomas "Charlie" Scott': 0.05641025641025641,
#  'Michael Barnwell "Mike" Silliman': 0.05641025641025641,
#  'John Kenneth "Ken" Spain': 0.05641025641025641,
#  'Joseph Henry "Jo-Jo" White': 0.05641025641025641}

# %%
for x in list(degree_centrality)[0:5]:
    print (x)
# Out:
# Gary Dwayne Payton
# Jason Frederick Kidd
# David Maurice Robinson
# Carmelo Kyan Anthony
# Charles Wade Barkley

# %% [markdown]
# ## 7. Generate a network visualization for the entire graph using a Kamada-Kawai force-directed layout.

# %%
#nx.draw_kamada_kawai(G, node_size=224, node_color='cyan', with_labels=True)
nx.draw_kamada_kawai(G, node_size=224, node_color='cyan',)

# %% [markdown]
# ## 8. Create and visualize an ego graph for the player with the highest betweenness centrality.

# %%
betweeness_centrality=dict(sorted(nx.betweenness_centrality(G).items(), key=lambda item: item[1], reverse=True))
#betweeness_centrality

# %%
highest_betweeness_centrality = max(betweeness_centrality.items(), key=lambda x: x[1])[0]
#Now we could plot the corresponding ego_graph with:

ego_g = nx.ego_graph(G, highest_betweeness_centrality)
d = dict(ego_g.degree)
d
# Out:
# {'Kevin Maurice Garnett': 11,
#  'Steven Delano "Steve" Smith': 11,
#  'Karl Malone': 11,
#  'Anfernee Deon "Penny" Hardaway': 11,
#  'Walter Ray Allen': 11,
#  'Alonzo Harding Mourning': 11,
#  'David Maurice Robinson': 11,
#  'Grant Henry Hill': 11,
#  'Charles Wade Barkley': 11,
#  'Gary Dwayne Payton': 22,
#  'Vincent Lamont "Vin" Baker': 11,
#  'Antonio Keithflen McDyess': 11,
#  "Shaquille Rashuan O'Neal": 11,
#  'Mitchell James "Mitch" Richmond, III': 11,
#  'Julius Shareef Abdur-Rahim': 11,
#  'Scottie Maurice Pippen': 11,
#  'John Houston Stockton': 11,
#  'Reginald Wayne "Reggie" Miller': 11,
#  'Hakeem Abdul Olajuwon': 11,
#  'Jason Frederick Kidd': 11,
#  'Timothy Duane "Tim" Hardaway': 11,
#  'Allan Wade Houston': 11,
#  'Vincent Lamar "Vince" Carter': 11}

# %%
nx.draw(ego_g, node_color='lightblue', 
        with_labels=True, 
        nodelist=d, 
        node_size=[d[k]*300 for k in d])

# %% [markdown]
# ## 9. Identify the communities within the entire graph and produce another visualization of it with the nodes color-coded by the community they belong to.

# %%
from networkx.algorithms.community.centrality import girvan_newman
import itertools

# %%
comp = girvan_newman(G)
for communities in itertools.islice(comp, 1):
    print(f'Communities: {tuple(sorted(c) for c in communities)}')
# Out:
# Communities: (['Allan Wade Houston', 'Allen Ezail Iverson', 'Alonzo Harding Mourning', "Amar'e Carsares Stoudemire", 'Andre Tyler Iguodala', 'Anthony Marshon Davis, Jr.', 'Antonio Keithflen McDyess', 'Carlos Austin Boozer, Jr.', 'Carmelo Kyan Anthony', 'Christopher Emmanuel "Chris" Paul', 'Christopher Wesson "Chris" Bosh', 'Chukwuemeka Noubuisi "Emeka" Okafor', 'DeMar Darnell DeRozan', 'DeMarcus Amir Cousins', 'Deron Michael Williams', 'Draymond Jamal Green', 'Dwight David Howard', 'Dwyane Tyrone Wade, Jr.', 'Gary Dwayne Payton', 'Harrison Bryce Jordan Barnes', 'Hyland DeAndre Jordan, Jr.', 'James Edward Harden, Jr.', 'Jason Frederick Kidd', 'Jimmy Butler III', 'Julius Shareef Abdur-Rahim', 'Kevin Maurice Garnett', 'Kevin Wayne Durant', 'Kevin Wesley Love', 'Klay Alexander Thompson', 'Kobe Bean Bryant', 'Kyle Lowry', 'Kyrie Andrew Irving', 'Lamar Joseph Odom', 'LeBron Raymone James', 'Michael Wesley Redd', 'Paul George', 'Richard Allen Jefferson', 'Russell Westbrook, Jr.', 'Shawn Dwayne Marion', 'Stephon Xavier Marbury', 'Steven Delano "Steve" Smith', 'Tayshaun Durell Prince', 'Timothy Duane "Tim" Hardaway', 'Timothy Theodore "Tim" Duncan', 'Tyson Cleotis Chandler', 'Vincent Lamar "Vince" Carter', 'Vincent Lamont "Vin" Baker', 'Walter Ray Allen'], ['Alvin Cyrrale Robertson', 'Anfernee Deon "Penny" Hardaway', 'Charles Daniel H. Smith', 'Charles Edward Smith, IV', 'Charles Wade Barkley', 'Christian Donald Laettner', 'Christopher Paul "Chris" Mullin', 'Clyde Austin Drexler', 'Daniel Lewis "Dan" Majerle', 'Daniel Ricardo "Danny" Manning', 'David Maurice Robinson', 'Earvin "Magic" Johnson, Jr.', 'Grant Henry Hill', 'Hakeem Abdul Olajuwon', 'Herman "J. R." Reid, Jr.', 'Hersey R. Hawkins, Jr.', 'Jeffrey "Jeff" Grayer', 'Jeffrey Stephen "Jeff" Turner', 'John Houston Stockton', 'Jon Francis Koncak', 'Joseph William "Joe" Kleine', 'Karl Malone', 'Larry Joe Bird', 'Michael Jeffrey Jordan', 'Mitchell James "Mitch" Richmond, III', 'Osie Leon Wood, III', 'Patrick Aloysius Ewing', 'Reginald Wayne "Reggie" Miller', 'Samuel Bruce "Sam" Perkins', 'Scottie Maurice Pippen', "Shaquille Rashuan O'Neal", 'Stacey Orlando Augmon', 'Stephen Todd "Steve" Alford', 'Vernell Eufaye "Bimbo" Coles', 'Vernon "Vern" Fleming', 'Wayman Lawrence Tisdale', 'William Lloyd "Willie" Anderson, Jr.'], ['Adrian Delano Dantley', 'Ernest "Ernie" Grunfeld', 'Kenneth Alan "Kenny" Carr', 'Michel Taylor "Tate" Armstrong', 'Mitchell William "Mitch" Kupchak', 'Philip Jackson "Phil" Ford, Jr.', 'Phillip Gregory "Phil" Hubbard', 'Scott Glenn May', 'Steven Bernard "Steve" Sheppard', 'Thomas Joseph "Tom" LaGarde', 'Walter Paul Davis', 'William Quinn Buckner'], ['Adrian Howard Smith', 'Alexander John "Alex" Groza', 'Burdette Eliele "Burdie" Haldorson', 'Carl Cecil Cain', 'Charles Frick "Chuck" Darling', 'Charles Monroe "Charlie" Hoag', 'Clifford Eugene "Cliff" Barker', 'Clyde Edward Lovellette', 'Dan Luther Pippin', 'Darrall Tucker Imhoff', 'Donald Argee "Don" Barksdale', 'Earl Allen Kelley', 'Frank Reilly McCabe', 'Gilbert "Gib" Ford', 'Gordon C. Carpenter', 'Howard Earl "Howie" Williams', 'James Patrick "Jim" Walsh', 'Jay Joseph Hoyland Arnette', 'Jerome Alan "Jerry" West', 'Jerry Ray Lucas', 'Jesse Banard Renick', 'John Frederick Keller', 'K. C. Jones', 'Kenneth Herman "Kenny" Rollins', 'Lester Everett "Les" Lane', 'Lewis William "Lew" Beck, Jr.', 'Marcus Ross "Marc" Freiberger', 'Melvin Dean Kelley', 'Oscar Palmer Robertson', 'Ralph Milton Beard, Jr.', 'Raymond George "Ray" Lumpp', 'Richard James "Dick" Boushka', 'Robert Albert "Bob" Kurland', 'Robert C. "R. C." Pitts', 'Robert Earl "Bob" Kenney', 'Robert Eugene "Bob" Jeangerard', 'Robert Lewis "Bob" Boozer', 'Robert Lloyd Jackson "Jack" Robinson', 'Ronald Paul "Ron" Tomsic', 'Ronald Yngve "Ron" Bontemps', 'Terence Gilbert "Terry" Dischinger', 'Victor Wayne Glasgow', 'Vincent Joseph "Vince" Boryla', 'Wallace Clayton "Wally" Jones', 'Walter Jones "Walt" Bellamy, Jr.', 'William Barner "Bill" Lienhard', 'William Best "Billy" Evans' ...

# %%
communities
# Out:
# ({'Allan Wade Houston',
#   'Allen Ezail Iverson',
#   'Alonzo Harding Mourning',
#   "Amar'e Carsares Stoudemire",
#   'Andre Tyler Iguodala',
#   'Anthony Marshon Davis, Jr.',
#   'Antonio Keithflen McDyess',
#   'Carlos Austin Boozer, Jr.',
#   'Carmelo Kyan Anthony',
#   'Christopher Emmanuel "Chris" Paul',
#   'Christopher Wesson "Chris" Bosh',
#   'Chukwuemeka Noubuisi "Emeka" Okafor',
#   'DeMar Darnell DeRozan',
#   'DeMarcus Amir Cousins',
#   'Deron Michael Williams',
#   'Draymond Jamal Green',
#   'Dwight David Howard',
#   'Dwyane Tyrone Wade, Jr.',
#   'Gary Dwayne Payton',
#   'Harrison Bryce Jordan Barnes',
#   'Hyland DeAndre Jordan, Jr.',
#   'James Edward Harden, Jr.',
#   'Jason Frederick Kidd',
#   'Jimmy Butler III',
#   'Julius Shareef Abdur-Rahim',
#   'Kevin Maurice Garnett',
#   'Kevin Wayne Durant',
#   'Kevin Wesley Love',
#   'Klay Alexander Thompson',
#   'Kobe Bean Bryant',
#   'Kyle Lowry',
#   'Kyrie Andrew Irving',
#   'Lamar Joseph Odom',
#   'LeBron Raymone James',
#   'Michael Wesley Redd',
#   'Paul George',
#   'Richard Allen Jefferson',
#   'Russell Westbrook, Jr.',
#   'Shawn Dwayne Marion',
#   'Stephon Xavier Marbury',
#   'Steven Delano "Steve" Smith',
#   'Tayshaun Durell Prince',
#   'Timothy Duane "Tim" Hardaway',
#   'Timothy Theodore "Tim" Duncan',
#   'Tyson Cleotis Chandler',
#   'Vincent Lamar "Vince" Carter',
#   'Vincent Lamont "Vin" Baker',
#   'Walter Ray Allen'},
#  {'Alvin Cyrrale Robertson',
#   'Anfernee Deon "Penny" Hardaway',
#   'Charles Daniel H. Smith',
#   'Charles Edward Smith, IV',
#   'Charles Wade Barkley',
#   'Christian Donald Laettner',
#   'Christopher Paul "Chris" Mullin',
#   'Clyde Austin Drexler',
#   'Daniel Lewis "Dan" Majerle',
#   'Daniel Ricardo "Danny" Manning',
#   'David Maurice Robinson',
#   'Earvin "Magic" Johnson, Jr.',
#   'Grant Henry Hill',
#   'Hakeem Abdul Olajuwon',
#   'Herman "J. R." Reid, Jr.',
#   'Hersey R. Hawkins, Jr.',
#   'Jeffrey "Jeff" Grayer',
#   'Jeffrey Stephen "Jeff" Turner',
#   'John Houston Stockton',
#   'Jon Francis Koncak',
#   'Joseph William "Joe" Kleine',
#   'Karl Malone',
#   'Larry Joe Bird',
#   'Michael Jeffrey Jordan',
#   'Mitchell James "Mitch" Richmond, III',
#   'Osie Leon Wood, III',
#   'Patrick Aloysius Ewing',
#   'Reginald Wayne "Reggie" Miller',
#   'Samuel Bruce "Sam" Perkins',
#   'Scottie Maurice Pippen',
#   "Shaquille Rashuan O'Neal",
#   'Stacey Orlando Augmon',
#   'Stephen Todd "Steve" Alford',
#   'Vernell Eufaye "Bimbo" Coles',
#   'Vernon "Vern" Fleming',
#   'Wayman Lawrence Tisdale',
#   'William Lloyd "Willie" Anderson, Jr.'},
#  {'Adrian Delano Dantley',
#   'Ernest "Ernie" Grunfeld',
#   'Kenneth Alan "Kenny" Carr',
#   'Michel Taylor "Tate" Armstrong',
#   'Mitchell William "Mitch" Kupchak',
#   'Philip Jackson "Phil" Ford, Jr.',
#   'Phillip Gregory "Phil" Hubbard',
#   'Scott Glenn May',
#   'Steven Bernard "Steve" Sheppard',
#   'Thomas Joseph "Tom" LaGarde',
#   'Walter Paul Davis',
#   'William Quinn Buckner'},
#  {'Adrian Howard Smith',
#   'Alexander John "Alex" Groza',
#   'Burdette Eliele "Burdie" Haldorson',
#   'Carl Cecil Cain',
#   'Charles Frick "Chuck" Darling',
#   'Charles Monroe "Charlie" Hoag',
#   'Clifford Eugene "Cliff" Barker',
#   'Clyde Edward Lovellette',
#   'Dan Luther Pippin',
#   'Darrall Tucker Imhoff',
#   'Donald Argee "Don" Barksdale',
#   'Earl Allen Kelley',
#   'Frank Reilly McCabe',
#   'Gilbert "Gib" Ford',
#   'Gordon C. Carpenter',
#   'Howard Earl "Howie" Williams',
#   'James Patrick "Jim" Walsh',
#   'Jay Joseph Hoyland Arnette',
#   'Jerome Alan "Jerry" West',
#   'Jerry Ray Lucas',
#   'Jesse Banard Renick',
#   'John Frederick Keller',
#   'K. C. Jones',
#   'Kenneth Herman "Kenny" Rollins',
#   'Lester Everett "Les" Lane',
#   'Lewis William "Lew" Beck, Jr.',
#   'Marcus Ross "Marc" Freiberger',
#   'Melvin Dean Kelley',
#   'Oscar Palmer Robertson',
#   'Ralph Milton Beard, Jr.',
#   'Raymond George "Ray" Lumpp',
#   'Richard James "Dick" Boushka',
#   'Robert Albert "Bob" Kurland',
#   'Robert C. "R. C." Pitts',
#   'Robert Earl "Bob" Kenney',
#   'Robert Eugene "Bob" Jeangerard',
#   'Robert Lewis "Bob" Boozer',
#   'Robert Lloyd Jackson "Jack" Robinson',
#   'Ronald Paul "Ron" Tomsic',
#   'Ronald Yngve "Ron" Bontemps',
#   'Terence Gilbert "Terry" Dischinger',
#   'Victor Wayne Glasgow',
#   'Vincent Joseph "Vince" Boryla',
#   'Wallace Clayton "Wally" Jones',
#   'Walter Jones "Walt" Bellamy, Jr.',
#   'William Barner "Bill" Lienhard',
#   'William Best "Billy" Evans',
#   'William Fenton "Bill" Russell',
#   'William Marion "Bill" Hougland'},
#  {'Arthur Owen "Art" Mollner',
#   'Carl Leslie Shy',
#   'Carl Stanley Knowles',
#   'Donald Arthur "Don" Piper',
#   'Duane Alexander Swanson',
#   'Francis Lee Johnson',
#   'Frank John Lubin',
#   'Jack Williamson Ragland',
#   'John Haskell "Tex" Gibbons',
#   'Joseph Cephis "Joe" Fortenberry',
#   'Ralph English Bishop',
#   'Samuel J. "Sam" Balter, Jr.',
#   'Willard Theodore Schmidt',
#   'William John "Bill" Wheatley'},
#  {'Charles Thomas "Tom" McMillen',
#   'Dwight Elmo Jones',
#   'James Ricardo "Jim" Forbes',
#   'James Turner "Jim" Brewer',
#   'Kenneth Bryan "Kenny" Davis',
#   'Kevin Francis Joyce',
#   'Michael Allen "Mike" Bantom',
#   'Paul Douglas "Doug" Collins',
#   'Robert Clyde "Bobby" Jones',
#   'Thomas Edward "Tom" Henderson',
#   'Tommy Loren Burleson',
#   'William Edward "Ed" Ratleff'},
#  {'George "Jiff" Wilson',
#   'Jeffrey Vincent "Jeff" Mullins',
#   'Jerry Franklin Shipp',
#   'John Paul "Pete" McCaffrey',
#   'Joseph Louis "Joe" Caldwell',
#   'Lawrence Harvey "Larry" Brown',
#   'Lucious Brown "Luke" Jackson, Jr.',
#   'Melvin Grant "Mel" Counts',
#   'Richard Allen "Dick" Davies',
#   'Velvet James "Jim" Barnes',
#   'Walter Raphael "Walt" Hazzard',
#   'William Warren "Bill" Bradley'},
#  {'Calvin Bernard "Cal" Fowler',
#   'Charles Thomas "Charlie" Scott',
#   'Donald Francis "Don" Dee',
#   'Glynn Saulters',
#   'James H. "Jim" King',
#   'John Kenneth "Ken" Spain',
#   'John Richard Clawson',
#   'Joseph Henry "Jo-Jo" White',
#   'Michael Barnwell "Mike" Silliman',
#   'Michael Thomas "Mike" Barrett',
#   'Spencer Haywood',
#   'Wilmer Frederick "Bill" Hosket'})

# %%
# %%capture
# !pip install python-louvain
from community import community_louvain
communities =community_louvain.best_partition(G)

# %%
communities
# Out:
# {'Julius Shareef Abdur-Rahim': 0,
#  'Walter Ray Allen': 0,
#  'Vincent Lamont "Vin" Baker': 0,
#  'Vincent Lamar "Vince" Carter': 0,
#  'Kevin Maurice Garnett': 0,
#  'Timothy Duane "Tim" Hardaway': 0,
#  'Allan Wade Houston': 0,
#  'Jason Frederick Kidd': 0,
#  'Antonio Keithflen McDyess': 0,
#  'Alonzo Harding Mourning': 0,
#  'Gary Dwayne Payton': 0,
#  'Steven Delano "Steve" Smith': 0,
#  'Stephen Todd "Steve" Alford': 1,
#  'Patrick Aloysius Ewing': 1,
#  'Vernon "Vern" Fleming': 1,
#  'Michael Jeffrey Jordan': 1,
#  'Joseph William "Joe" Kleine': 1,
#  'Jon Francis Koncak': 1,
#  'Christopher Paul "Chris" Mullin': 1,
#  'Samuel Bruce "Sam" Perkins': 1,
#  'Alvin Cyrrale Robertson': 1,
#  'Wayman Lawrence Tisdale': 1,
#  'Jeffrey Stephen "Jeff" Turner': 1,
#  'Osie Leon Wood, III': 1,
#  'William Lloyd "Willie" Anderson, Jr.': 1,
#  'Stacey Orlando Augmon': 1,
#  'Vernell Eufaye "Bimbo" Coles': 1,
#  'Jeffrey "Jeff" Grayer': 1,
#  'Hersey R. Hawkins, Jr.': 1,
#  'Daniel Lewis "Dan" Majerle': 1,
#  'Daniel Ricardo "Danny" Manning': 1,
#  'Herman "J. R." Reid, Jr.': 1,
#  'Mitchell James "Mitch" Richmond, III': 1,
#  'David Maurice Robinson': 1,
#  'Charles Daniel H. Smith': 1,
#  'Charles Edward Smith, IV': 1,
#  'Carmelo Kyan Anthony': 5,
#  'Carlos Austin Boozer, Jr.': 5,
#  'Timothy Theodore "Tim" Duncan': 5,
#  'Allen Ezail Iverson': 5,
#  'LeBron Raymone James': 5,
#  'Richard Allen Jefferson': 5,
#  'Stephon Xavier Marbury': 5,
#  'Shawn Dwayne Marion': 5,
#  'Lamar Joseph Odom': 5,
#  'Chukwuemeka Noubuisi "Emeka" Okafor': 5,
#  "Amar'e Carsares Stoudemire": 5,
#  'Dwyane Tyrone Wade, Jr.': 5,
#  'Christopher Wesson "Chris" Bosh': 5,
#  'Kobe Bean Bryant': 5,
#  'Dwight David Howard': 5,
#  'Christopher Emmanuel "Chris" Paul': 5,
#  'Tayshaun Durell Prince': 5,
#  'Michael Wesley Redd': 5,
#  'Deron Michael Williams': 5,
#  'Tyson Cleotis Chandler': 5,
#  'Anthony Marshon Davis, Jr.': 5,
#  'Kevin Wayne Durant': 5,
#  'James Edward Harden, Jr.': 5,
#  'Andre Tyler Iguodala': 5,
#  'Kevin Wesley Love': 5,
#  'Russell Westbrook, Jr.': 5,
#  'Harrison Bryce Jordan Barnes': 5,
#  'Jimmy Butler III': 5,
#  'DeMarcus Amir Cousins': 5,
#  'DeMar Darnell DeRozan': 5,
#  'Paul George': 5,
#  'Draymond Jamal Green': 5,
#  'Kyrie Andrew Irving': 5,
#  'Hyland DeAndre Jordan, Jr.': 5,
#  'Kyle Lowry': 5,
#  'Klay Alexander Thompson': 5,
#  'Michel Taylor "Tate" Armstrong': 7,
#  'William Quinn Buckner': 7,
#  'Kenneth Alan "Kenny" Carr': 7,
#  'Adrian Delano Dantley': 7,
#  'Walter Paul Davis': 7,
#  'Philip Jackson "Phil" Ford, Jr.': 7,
#  'Ernest "Ernie" Grunfeld': 7,
#  'Phillip Gregory "Phil" Hubbard': 7,
#  'Mitchell William "Mitch" Kupchak': 7,
#  'Thomas Joseph "Tom" LaGarde': 7,
#  'Scott Glenn May': 7,
#  'Steven Bernard "Steve" Sheppard': 7,
#  'Jay Joseph Hoyland Arnette': 8,
#  'Walter Jones "Walt" Bellamy, Jr.': 8,
#  'Robert Lewis "Bob" Boozer': 8,
#  'Terence Gilbert "Terry" Dischinger': 8,
#  'Burdette Eliele "Burdie" Haldorson': 8,
#  'Darrall Tucker Imhoff': 8,
#  'Earl Allen Kelley': 8,
#  'Lester Everett "Les" Lane': 8,
#  'Jerry Ray Lucas': 8,
#  'Oscar Palmer Robertson': 8,
#  'Adrian Howard Smith': 8,
#  'Jerome Alan "Jerry" West': 8,
#  'Samuel J. "Sam" Balter, Jr.': 9,
#  'Ralph English Bishop': 9,
#  'Joseph Cephis "Joe" Fortenberry': 9,
#  'John Haskell "Tex" Gibbons': 9,
#  'Francis Lee Johnson': 9,
#  'Carl Stanley Knowles': 9,
#  'Frank John Lubin': 9,
#  'Arthur Owen "Art" Mollner': 9,
#  'Donald Arthur "Don" Piper': 9,
#  'Jack Williamson Ragland': 9,
#  'Willard Theodore Schmidt': 9,
#  'Carl Leslie Shy': 9,
#  'Duane Alexander Swanson': 9,
#  'William John "Bill" Wheatley': 9,
#  'Michael Allen "Mike" Bantom': 10,
#  'James Turner "Jim" Brewer': 10,
#  'Tommy Loren Burleson': 10,
#  'Paul Douglas "Doug" Collins': 10,
#  'Kenneth Bryan "Kenny" Davis': 10,
#  'James Ricardo "Jim" Forbes': 10,
#  'Thomas Edward "Tom" Henderson': 10,
#  'Robert Clyde "Bobby" Jones': 10,
#  'Dwight Elmo Jones': 10,
#  'Kevin Francis Joyce': 10,
#  'Charles Thomas "Tom" McMillen': 10,
#  'William Edward "Ed" Ratleff': 10,
#  'Clifford Eugene "Cliff" Barker': 2,
#  'Donald Argee "Don" Barksdale': 2,
#  'Ralph Milton Beard, Jr.': 2,
#  'Lewis William "Lew" Beck, Jr.': 2,
#  'Vincent Joseph "Vince" Boryla': 2,
#  'Gordon C. Carpenter': 2,
#  'Alexander John "Alex" Groza': 2,
#  'Wallace Clayton "Wally" Jones': 2,
#  'Robert Albert "Bob" Kurland': 2,
#  'Raymond George "Ray" Lumpp': 2,
#  'Robert C. "R. C." Pitts': 2,
#  'Jesse Banard Renick': 2,
#  'Robert Lloyd Jackson "Jack" Robinson': 2,
#  'Kenneth Herman "Kenny" Rollins': 2,
#  'Charles Wade Barkley': 1,
#  'Larry Joe Bird': 1,
#  'Clyde Austin Drexler': 1,
#  'Earvin "Magic" Johnson, Jr.': 1,
#  'Christian Donald Laettner': 1,
#  'Karl Malone': 1,
#  'Scottie Maurice Pippen': 1,
#  'John Houston Stockton': 1,
#  'Anfernee Deon "Penny" Hardaway': 1,
#  'Grant Henry Hill': 1,
#  'Reginald Wayne "Reggie" Miller': 1,
#  'Hakeem Abdul Olajuwon': 1,
#  "Shaquille Rashuan O'Neal": 1,
#  'Velvet James "Jim" Barnes': 3,
#  'William Warren "Bill" Bradley': 3,
#  'Lawrence Harvey "Larry" Brown': 3,
#  'Joseph Louis "Joe" Caldwell': 3,
#  'Melvin Grant "Mel" Counts': 3,
#  'Richard Allen "Dick" Davies': 3,
#  'Walter Raphael "Walt" Hazzard': 3,
#  'Lucious Brown "Luke" Jackson, Jr.': 3,
#  'John Paul "Pete" McCaffrey': 3,
#  'Jeffrey Vincent "Jeff" Mullins': 3,
#  'Jerry Franklin Shipp': 3,
#  'George "Jiff" Wilson': 3,
#  'Michael Thomas "Mike" Barrett': 4,
#  'John Richard Clawson': 4,
#  'Donald Francis "Don" Dee': 4,
#  'Calvin Bernard "Cal" Fowler': 4,
#  'Spencer Haywood': 4,
#  'Wilmer Frederick "Bill" Hosket': 4,
#  'James H. "Jim" King': 4,
#  'Glynn Saulters': 4,
#  'Charles Thomas "Charlie" Scott': 4,
#  'Michael Barnwell "Mike" Silliman': 4,
#  'John Kenneth "Ken" Spain': 4,
#  'Joseph Henry "Jo-Jo" White': 4,
#  'Ronald Yngve "Ron" Bontemps': 6,
#  'Marcus Ross "Marc" Freiberger': 6,
#  'Victor Wayne Glasgow': 6,
#  'Charles Monroe "Charlie" Hoag': 6,
#  'William Marion "Bill" Hougland': 6,
#  'John Frederick Keller': 6,
#  'Melvin Dean Kelley': 6,
#  'Robert Earl "Bob" Kenney': 6,
#  'William Barner "Bill" Lienhard': 6,
#  'Clyde Edward Lovellette': 6,
#  'Frank Reilly McCabe': 6,
#  'Dan Luther Pippin': 6,
#  'Howard Earl "Howie" Williams': 6,
#  'Richard James "Dick" Boushka': 8,
#  'Carl Cecil Cain': 8,
#  'Charles Frick "Chuck" Darling': 8,
#  'William Best "Billy" Evans': 8,
#  'Gilbert "Gib" Ford': 8,
#  'Robert Eugene "Bob" Jeangerard': 8,
#  'K. C. Jones': 8,
#  'William Fenton "Bill" Russell': 8,
#  'Ronald Paul "Ron" Tomsic': 8,
#  'James Patrick "Jim" Walsh': 8}

# %% [markdown]
# ## Bonus: Hierarchical Graphs
#
# Thus far, we have analyzed graphs where the nodes represented individual players and the edges represented Olympic games that they have competed in together. We can analyze the data at a higher level if we wanted to, strippping out the players as entities and analyzing the data at the Games level. To do this, we would need to reconstruct the graph so that the *Games* field represents the entities and then use the player names as the edge criteria so that there would be an edge between two Olympic games if an player played in both of them. You already have the tools in your toolbox to be able to do this, so give it a try.

# %% [markdown]
# ### Create a graph with Games as the entities and then print out the graph statistics.

# %%
G = nx.from_pandas_edgelist(basketball3,  source='Games', target='Name_x')

# %% [markdown]
# ### Generate a network visualization of this graph using the layout of your choice.
